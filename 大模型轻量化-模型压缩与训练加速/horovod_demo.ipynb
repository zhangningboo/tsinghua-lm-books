# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# %pip install horovod
# Out:
# Looking in indexes: https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: horovod in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (0.28.1)
# Requirement already satisfied: cloudpickle in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (from horovod) (3.1.2)
# Requirement already satisfied: psutil in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (from horovod) (7.1.3)
# Requirement already satisfied: pyyaml in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (from horovod) (6.0.3)
# Requirement already satisfied: packaging in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (from horovod) (25.0)
# Requirement already satisfied: cffi>=1.4.0 in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (from horovod) (2.0.0)
# Requirement already satisfied: pycparser in /data/sdb1/zhangningboo/miniforge3/envs/frome_zero_llm/lib/python3.10/site-packages (from cffi>=1.4.0->horovod) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 使用horovod进行分布式训练
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

import horovod.torch as hvd
import os
import time

# %%
# 初始化Horovod
hvd.init()
